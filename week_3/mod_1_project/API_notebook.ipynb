# %% [markdown]
# ## Final Project Submission

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd
import json 
import requests

# %%
people = requests.get('https://api.themoviedb.org/3/search/movie?api_key=6b5764a892f61d2baeaf46482cb33b29&language=en-US&query=titanic&page=1&include_adult=false')
people.content
# Out:
# b'{"page":1,"total_results":111,"total_pages":6,"results":[{"popularity":25.656,"vote_count":16016,"video":false,"poster_path":"\\/kHXEpyfl6zqn8a6YuozZUujufXf.jpg","id":597,"adult":false,"backdrop_path":"\\/xqQztbT6KlPLQLlRtNHoXivEMZA.jpg","original_language":"en","original_title":"Titanic","genre_ids":[18,53,10749],"title":"Titanic","vote_average":7.8,"overview":"101-year-old Rose DeWitt Bukater tells the story of her life aboard the Titanic, 84 years later. A young Rose boards the ship with her mother and fianc\xc3\xa9. Meanwhile, Jack Dawson and Fabrizio De Rossi win third-class tickets aboard the ship. Rose tells the whole story from Titanic\'s departure through to its death\xe2\x80\x94on its first and last voyage\xe2\x80\x94on April 15, 1912.","release_date":"1997-11-18"},{"popularity":8.177,"vote_count":115,"video":false,"poster_path":"\\/tUSMxX60DGkTIoiDnUNNrJLtP3t.jpg","id":44918,"adult":false,"backdrop_path":"\\/9nost5nL1EaqgcGpOpC550M0x9A.jpg","original_language":"en","orig
# ...

# %%
json.loads(people.content)
# Out:
# {'page': 1,
#  'total_results': 111,
#  'total_pages': 6,
#  'results': [{'popularity': 25.656,
#    'vote_count': 16016,
#    'video': False,
#    'poster_path': '/kHXEpyfl6zqn8a6YuozZUujufXf.jpg',
#    'id': 597,
#    'adult': False,
#    'backdrop_path': '/xqQztbT6KlPLQLlRtNHoXivEMZA.jpg',
#    'original_language': 'en',
#    'original_title': 'Titanic',
#    'genre_ids': [18, 53, 10749],
#    'title': 'Titanic',
#    'vote_average': 7.8,
#    'overview': "101-year-old Rose DeWitt Bukater tells the story of her life aboard the Titanic, 84 years later. A young Rose boards the ship with her mother and fiancé. Meanwhile, Jack Dawson and Fabrizio De Rossi win third-class tickets aboard the ship. Rose tells the whole story from Titanic's departure through to its death—on its first and last voyage—on April 15, 1912.",
#    'release_date': '1997-11-18'},
#   {'popularity': 8.177,
#    'vote_count': 115,
#    'video': False,
#    'poster_path': '/tUSMxX60DGkTIoiDnUNNrJLtP3t.jpg',
# ...

# %%
page = 1

while page <= 500:
    country = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=6b5764a892f61d2baeaf46482cb33b29&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=' + str(page))
    page = page + 1
                           
json.loads(country.content)
# Out:
# {'page': 500,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 6.659,
#    'vote_count': 88,
#    'video': False,
#    'poster_path': '/85LQ2ZShYhHJcndyVqXoPf7AxK4.jpg',
#    'id': 32054,
#    'adult': False,
#    'backdrop_path': '/5E3s6hw7NsesDB8QcivEtm40tvI.jpg',
#    'original_language': 'en',
#    'original_title': 'Hope and Glory',
#    'genre_ids': [35, 18, 36, 10752],
#    'title': 'Hope and Glory',
#    'vote_average': 6.8,
#    'overview': 'Director John Boorman drew from his own childhood experiences for this coming-of-age tale about a boy growing up in and around London during World War II. For young Billy Rowan, the nightly bombings provide a frightening show, but they include opportunities to rummage through the rubble with friends in the mornings. As Billy plays, his family struggles to remain intact as they suffer through the anguish and losses of wartime.',
#    'release_date': '1987-08-01'},
#   {'popularity': 6.659,
# ...

# %%
country = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=6b5764a892f61d2baeaf46482cb33b29&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=1')
json.loads(country.content)
# Out:
# {'page': 1,
#  'total_results': 10000,
#  'total_pages': 500,
#  'results': [{'popularity': 1403.185,
#    'vote_count': 585,
#    'video': False,
#    'poster_path': '/uPGq1mkEXznUpapDmOSxbsybjfp.jpg',
#    'id': 475303,
#    'adult': False,
#    'backdrop_path': '/6fkqwqLEcDZOEAnBBfKAniwNxtx.jpg',
#    'original_language': 'en',
#    'original_title': 'A Rainy Day in New York',
#    'genre_ids': [35, 10749],
#    'title': 'A Rainy Day in New York',
#    'vote_average': 6.7,
#    'overview': "Two young people arrive in New York to spend a weekend, but once they arrive they're met with bad weather and a series of adventures.",
#    'release_date': '2019-07-26'},
#   {'popularity': 323.546,
#    'vote_count': 2478,
#    'video': False,
#    'poster_path': '/xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg',
#    'id': 419704,
#    'adult': False,
#    'backdrop_path': '/5BwqwxMEjeFtdknRV792Svo0K1v.jpg',
#    'original_language': 'en',
#    'original_title': 'Ad Astra',
# ...

# %%
total_results =[]

for page1 in range(1, 501):
    url = "https://api.themoviedb.org/3/discover/movie?api_key=6b5764a892f61d2baeaf46482cb33b29&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=" + str(page1)
    print('Downloading', url)
    response = requests.get(url)
    data = response.json()
    total_results = total_results + data['results']
len(total_results)
total_results
# Out:
# ...
# ...
#   'original_language': 'en',
#   'original_title': 'Dangerous Beauty',
#   'genre_ids': [18, 10749],
#   'title': 'Dangerous Beauty',
#   'vote_average': 7.1,
#   'overview': "Veronica is brilliant, gifted and beautiful, but the handsome aristocrat she loves, Marco Venier, cannot marry her because she is penniless and of questionable family. So Veronica's mother, Paola, teaches her to become a courtesan, one of the exotic companions favored by the richest and most powerful Venetian men. Veronica courageously uses her charms to change destiny -- and to give herself a chance at true love.",
#   'release_date': '1998-02-20'},
#  {'popularity': 16.618,
#   'id': 745,
#   'video': False,
#   'vote_count': 7068,
#   'vote_average': 7.9,
#   'title': 'The Sixth Sense',
#   'release_date': '1999-08-06',
#   'original_language': 'en',
#   'original_title': 'The Sixth Sense',
#   'genre_ids': [9648, 53, 18],
#   'backdrop_path': '/1X6F9OvfaWl6AGcCdqYl8icxG9z.jpg',
#   'adult': False,
# ...

# %%
total_results
# Out:
# [{'popularity': 1403.185,
#   'vote_count': 585,
#   'video': False,
#   'poster_path': '/uPGq1mkEXznUpapDmOSxbsybjfp.jpg',
#   'id': 475303,
#   'adult': False,
#   'backdrop_path': '/6fkqwqLEcDZOEAnBBfKAniwNxtx.jpg',
#   'original_language': 'en',
#   'original_title': 'A Rainy Day in New York',
#   'genre_ids': [35, 10749],
#   'title': 'A Rainy Day in New York',
#   'vote_average': 6.7,
#   'overview': "Two young people arrive in New York to spend a weekend, but once they arrive they're met with bad weather and a series of adventures.",
#   'release_date': '2019-07-26'},
#  {'popularity': 323.546,
#   'vote_count': 2478,
#   'video': False,
#   'poster_path': '/xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg',
#   'id': 419704,
#   'adult': False,
#   'backdrop_path': '/5BwqwxMEjeFtdknRV792Svo0K1v.jpg',
#   'original_language': 'en',
#   'original_title': 'Ad Astra',
#   'genre_ids': [12, 18, 9648, 878, 53],
#   'title': 'Ad Astra',
#   'vote_average': 6,
# ...

# %%
(total_results)
# Out:
# list

# %%
genre = requests.get('https://api.themoviedb.org/3/genre/movie/list?api_key=6b5764a892f61d2baeaf46482cb33b29&language=en-US')
genre.json()
# Out:
# {'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 16, 'name': 'Animation'},
#   {'id': 35, 'name': 'Comedy'},
#   {'id': 80, 'name': 'Crime'},
#   {'id': 99, 'name': 'Documentary'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 14, 'name': 'Fantasy'},
#   {'id': 36, 'name': 'History'},
#   {'id': 27, 'name': 'Horror'},
#   {'id': 10402, 'name': 'Music'},
#   {'id': 9648, 'name': 'Mystery'},
#   {'id': 10749, 'name': 'Romance'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 10770, 'name': 'TV Movie'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 10752, 'name': 'War'},
#   {'id': 37, 'name': 'Western'}]}

# %%
movie_list = []

for record in total_results:
    
    movie_list.append(record)
     
movie_list
# Out:
# [{'popularity': 1403.185,
#   'vote_count': 585,
#   'video': False,
#   'poster_path': '/uPGq1mkEXznUpapDmOSxbsybjfp.jpg',
#   'id': 475303,
#   'adult': False,
#   'backdrop_path': '/6fkqwqLEcDZOEAnBBfKAniwNxtx.jpg',
#   'original_language': 'en',
#   'original_title': 'A Rainy Day in New York',
#   'genre_ids': [35, 10749],
#   'title': 'A Rainy Day in New York',
#   'vote_average': 6.7,
#   'overview': "Two young people arrive in New York to spend a weekend, but once they arrive they're met with bad weather and a series of adventures.",
#   'release_date': '2019-07-26'},
#  {'popularity': 323.546,
#   'vote_count': 2478,
#   'video': False,
#   'poster_path': '/xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg',
#   'id': 419704,
#   'adult': False,
#   'backdrop_path': '/5BwqwxMEjeFtdknRV792Svo0K1v.jpg',
#   'original_language': 'en',
#   'original_title': 'Ad Astra',
#   'genre_ids': [12, 18, 9648, 878, 53],
#   'title': 'Ad Astra',
#   'vote_average': 6,
# ...

# %%
df = pd.DataFrame(total_results)
df
# Out:
#       popularity  vote_count  video                       poster_path      id  \
# 0       1403.185         585  False  /uPGq1mkEXznUpapDmOSxbsybjfp.jpg  475303
# 1        323.546        2478  False  /xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg  419704
# 2        247.587         525  False  /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg  454626
# 3        233.733        1864  False  /bB42KDdfWkOvmzmYkmK58ZlCa9P.jpg  512200
# 4        228.878         145  False  /4U7hpTK0XTQBKT5X60bKmJd05ha.jpg  570670
# ...          ...         ...    ...                               ...     ...
# 9995       6.653          77  False  /vDyCsKerUVU2tKV9K7zyOOcdvLj.jpg   36797
# 9996       6.652         159  False  /w5IpcxxQdJI32ivbaldzfopDHrK.jpg  340357
# 9997       6.650          87  False  /p4L5DM3ZeEuAawFxd2ftgISQMZQ.jpg  438457
# 9998       6.650         150  False  /u23CCG87bWtpnPuSLMWpLkdK75H.jpg   12611
# 9999       6.650         114  False  /5JqamPZC7W5rzRNweMGhqltcsIV.jpg   14237
#
# ...

# %%
df.sort_values(['release_date'])
# Out:
#       popularity  vote_count  video                       poster_path      id  \
# 390       22.810           1  False  /metXmWgqY4WudeRqaiLMbDGSWCH.jpg  674270
# 2625      11.549           0  False                              None  600950
# 8725       7.091         218  False  /y3A15HpugKsPjVyxKa9POLTEX6B.jpg     160
# 1204      15.460          49  False   /ZLOgI7KjtWby1NEg2pjU2Id60W.jpg   49280
# 3612      10.110         845  False  /zztHYAfSecYuaDyIjQudjKaOLLY.jpg     775
# ...          ...         ...    ...                               ...     ...
# 3336      10.480           0  False  /6rsLfXqlZSXa6zLfbofHVhXs8Yr.jpg  447365
# 1333      14.911           0  False  /detm29wsfhS1bz5YdURvDePiUY3.jpg  504075
# 4871       8.917           0  False                              None  425274
# 6419       8.028           0  False  /lV5qk31axl9mo0uq9L4Jkmuzrbq.jpg  374771
# 9057       6.977           0  False  /5xDCweuDmdJiTPcXcN5KIDJenLK.jpg  425770
#
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head(60)
# Out:
#     popularity  vote_count  video                       poster_path      id  \
# 0     1403.185         585  False  /uPGq1mkEXznUpapDmOSxbsybjfp.jpg  475303
# 1      323.546        2478  False  /xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg  419704
# 2      247.587         525  False  /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg  454626
# 3      233.733        1864  False  /bB42KDdfWkOvmzmYkmK58ZlCa9P.jpg  512200
# 4      228.878         145  False  /4U7hpTK0XTQBKT5X60bKmJd05ha.jpg  570670
# 5      176.819        4728  False  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg  496243
# 6      127.227        2591  False  /pjeMs3yqRmFL3giJy4PMXWZTTPa.jpg  330457
# 7      124.936          36  False  /qZ1KAgfdeNbzrNYKW4BIRHdEBJ9.jpg  666750
# 8      124.263         918  False  /h4VB6m0RwcicVEZvzftYZyKXs6K.jpg  495764
# 9      110.740         547  False  /1DPUFG6QnGqzpvEaDEv7TaepycM.jpg  458897
# 10     108.706           7  False  /2UPHyMm8fE22yvTFVGu1LW2nVF0.jpg  496891
# ...
